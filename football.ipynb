# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('data/results.csv')

# %%
dataset.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
dataset.head(20)
# Out:
#           date         home_team away_team  home_score  away_score tournament  \
# 0   1872-11-30          Scotland   England           0           0   Friendly
# 1   1873-03-08           England  Scotland           4           2   Friendly
# 2   1874-03-07          Scotland   England           2           1   Friendly
# 3   1875-03-06           England  Scotland           2           2   Friendly
# 4   1876-03-04          Scotland   England           3           0   Friendly
# 5   1876-03-25          Scotland     Wales           4           0   Friendly
# 6   1877-03-03           England  Scotland           1           3   Friendly
# 7   1877-03-05             Wales  Scotland           0           2   Friendly
# 8   1878-03-02          Scotland   England           7           2   Friendly
# 9   1878-03-23          Scotland     Wales           9           0   Friendly
# 10  1879-01-18           England     Wales           2           1   Friendly
# ...

# %%
dataset.describe()
# Out:
#          home_score    away_score
# count  39050.000000  39050.000000
# mean       1.739974      1.179846
# std        1.730503      1.378580
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       31.000000     21.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39050 entries, 0 to 39049
# Data columns (total 9 columns):
# date          39050 non-null object
# home_team     39050 non-null object
# away_team     39050 non-null object
# home_score    39050 non-null int64
# away_score    39050 non-null int64
# tournament    39050 non-null object
# city          39050 non-null object
# country       39050 non-null object
# neutral       39050 non-null bool
# dtypes: bool(1), int64(2), object(6)
# memory usage: 2.4+ MB

# %%
X = dataset.iloc[:, 1:5].values
y = dataset.iloc[:, 8].values

# %%
X.shape,y.shape
# Out:
# ((39050, 4), (39050,))

# %%
X = dataset.iloc[:, 1:5]
y = dataset.iloc[:, 8]

# %%
X,y
# Out:
# (              home_team         away_team  home_score  away_score
#  0              Scotland           England           0           0
#  1               England          Scotland           4           2
#  2              Scotland           England           2           1
#  3               England          Scotland           2           2
#  4              Scotland           England           3           0
#  5              Scotland             Wales           4           0
#  6               England          Scotland           1           3
#  7                 Wales          Scotland           0           2
#  8              Scotland           England           7           2
#  9              Scotland             Wales           9           0
#  10              England             Wales           2           1
#  11              England          Scotland           5           4
#  12                Wales          Scotland           0           3
# ...

# %%
dataset.isnull()
# Out:
#         date  home_team  away_team  home_score  away_score  tournament   city  \
# 0      False      False      False       False       False       False  False
# 1      False      False      False       False       False       False  False
# 2      False      False      False       False       False       False  False
# 3      False      False      False       False       False       False  False
# 4      False      False      False       False       False       False  False
# 5      False      False      False       False       False       False  False
# 6      False      False      False       False       False       False  False
# 7      False      False      False       False       False       False  False
# 8      False      False      False       False       False       False  False
# 9      False      False      False       False       False       False  False
# 10     False      False      False       False       False       False  False
# ...

# %%
X = dataset.iloc[:, 1:5].values
y = dataset.iloc[:, 8].values

# %%
X.shape,y.shape
# Out:
# ((39050, 4), (39050,))

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
state = LabelEncoder()

# %%
X[:, 3] = state.fit_transform(X[:, 3])

# %%
X[:4, :]
# Out:
# array([['Scotland', 'England', 0, 0],
#        ['England', 'Scotland', 4, 2],
#        ['Scotland', 'England', 2, 1],
#        ['England', 'Scotland', 2, 2]], dtype=object)

# %%
X[:4, 1]
# Out:
# array(['England', 'Scotland', 'England', 'Scotland'], dtype=object)

# %%
X[:1, :]
# Out:
# array([['Scotland', 'England', 0, 0]], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,y_train,x_valid,y_valid=train_test_split(x,y,test_size=0.10,random_state=4)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-ae4bf08b45bb> in <module>()
# ----> 1 reg.fit(x_train,y_train)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
from fake_useragent.settings import DB
print(DB)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-cb04c1e3fc43> in <module>()
# ----> 1 from fake_useragent.settings import DB
#       2 print(DB)
#
# ModuleNotFoundError: No module named 'fake_useragent'

# %%
reg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-ae4bf08b45bb> in <module>()
# ----> 1 reg.fit(x_train,y_train)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
reg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-ae4bf08b45bb> in <module>()
# ----> 1 reg.fit(x_train,y_train)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
from fake_useragent import UserAgent
on calling ua = UserAgent() or ua = UserAgent(cache=False)
# Out:
#   File "<ipython-input-1-f573c6b3fcf8>", line 2
#     on calling ua = UserAgent() or ua = UserAgent(cache=False)
#              ^
# SyntaxError: invalid syntax

# %%
print("my name is {0} and age is{1}".format("himanshu", 20))
# Out:
# my name is himanshu and age is20

# %%
print('we\'re going to...')
# Out:
# we're going to...
